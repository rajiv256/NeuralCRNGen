# %%
using Catalyst
using ColorSchemes
using Dictionaries
using DifferentialEquations
using Formatting
using IterTools
using LaTeXStrings
using LinearAlgebra
using NNlib
using Noise
using Plots
using Random
using ReactionNetworkImporters
using Statistics

include("utils.jl")
include("datasets.jl")
Random.seed!(1224)
# Out:
# TaskLocalRNG()

# %%
train = create_annular_rings_dataset(100)
val = create_annular_rings_dataset(50)

x = getindex.(train, 1)
y = getindex.(train, 2)
labels = getindex.(train, 3)

scatter(x, y, group=labels)

# %%
function create_params(; dims=3, t0=0.0, t1=1.0, h=0.1)
    params = []

    push!(params, Float32(dims))

    theta = rand(Normal(0.5, 0.1), dims^2)
    append!(params, theta)
    beta = ones(dims)*0.1
    append!(params, beta)

    w = randn(dims)
    append!(params, w)

    push!(params, h)

    push!(params, t0)
    push!(params, t1)

    for i in eachindex(params)
        params = 1.0 * params
    end

    return params
end

params = create_params(h=0.5)
# Out:
# 19-element Vector{Float64}:
#  3.0
#  0.38302410873345555
#  0.24326939935139594
#  0.4520942729274006
#  0.3667939372960045
#  0.5707129476718132
#  0.5579336045458929
#  0.49069807549274685
#  0.44856222258192424
#  0.4155931545626239
#  0.1
#  0.1
#  0.1
#  0.8780607466448961
#  0.4931506457558921
#  1.7242059835212562
#  0.5
#  0.0
#  1.0

# %%
function f(u, xAndp, t)
    x = xAndp[1:3]
    p = xAndp[4:end]
    dims, theta, beta, w, h, _, _ = sequester_params(p)
    hvec = [h, h, h]
    fmat = hvec + theta.*u + beta - u.*u 
#     fmat = hvec + (theta * x + beta) .* u - u .* u
    # fmat = theta*u
    @assert length(fmat) == length(u)
    return fmat
end

function forward!(du, u, xAndp, t)
    fmat = f(u, xAndp, t)
    for i in eachindex(fmat)
        du[i] = fmat[i] 
    end
end

# Calculates the final hidden state of the neural ode
function forward_node(u0, xAndp, tspan)
    prob = ODEProblem(forward!, u0, tspan, xAndp)
    sol = solve(prob, Tsit5(), reltol=1e-8, abstol=1e-12, save_on=false)
    return sol
end
# Out:
# forward_node (generic function with 1 method)

# %%
function backward!(du, u, sAndp, t)
    func = -f(u, sAndp, t)
    for i in eachindex(func)
        du[i] = func[i]
    end
end

function backward_node(s0, sAndp, tspan)
    prob = ODEProblem(backward!, s0, tspan, sAndp)
    sol = solve(prob, Tsit5(), reltol=1e-8, abstol=1e-12, save_on=false)
    return sol
end
# Out:
# backward_node (generic function with 1 method)

# %%
DIMS = 3
tspan = (0.0, 0.6)
rtspan = reverse(tspan)
fsol = nothing
bsol = nothing
idealz = []
odez = []
idealx = []
odex = []
for trindex in eachindex(train)
    x = train[trindex][1:2]
    y = train[trindex][3]
    append!(x, 0.0)

    println("ODE | Input | ", x)
    dims, theta, beta, w, h, t0, t1 = sequester_params(params)
    reluval = relu.(x + theta*x + beta)
    # relualt = x + relu.(theta*x + beta)
    println("ODE | Ideal Before ReLU | ",  x + theta*x + beta)
    println("ODE | Ideal ReLU | Val1 | ", reluval)
    # println("ODE | Ideal ReLU | Val2 | ", relualt)

    xAndp = []
    append!(xAndp, x)
    append!(xAndp, params)

    fsol = forward_node(x, xAndp, tspan)
    println("ODE | z @ t=T | ", fsol[end])
    z = fsol[end]

    zAndp = []
    append!(zAndp, z)
    append!(zAndp, params)
    bsol = backward_node(z, zAndp, tspan)
    println("ODE | Input | ", x)
    println("ODE | z @ t=0 | ", bsol[end])
    println("===========================")

    ## Tracking
    push!(idealx, x)
    push!(idealz, reluval)
    push!(odex, bsol[end])
    push!(odez, fsol[end])
    # break
end
nothing
# Out:
# ODE | Input | Float32[-0.644075, -0.6821511, 0.0]
# ODE | Ideal Before ReLU | [-1.1298861635266906, -1.454274483645586, -0.6326943515091616]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[-0.35474646, -0.30750373, 0.23794393]
# ODE | Input | Float32[-0.644075, -0.6821511, 0.0]
# ODE | z @ t=0 | Float32[-0.5386686, -0.54891765, -0.042492166]
# ===========================
# ODE | Input | Float32[-0.3118192, -0.09033434, 0.0]
# ODE | Ideal Before ReLU | [-0.37682772059457026, -0.2549575096324561, -0.10751065776661811]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[-0.027208194, 0.19776802, 0.27475443]
# ODE | Input | Float32[-0.3118192, -0.09033434, 0.0]
# ODE | z @ t=0 | Float32[-0.27416873, -0.10520418, -0.035835557]
# ===========================
# ODE | Input | Float32[0.38066703, 0.92237866, 0.0]
# ODE | Ideal Before ReLU | [1.083567124431872, 1.8788954244790634, 0.8516252547950416]
# ODE | Ideal ReLU | Val1 | [1.083567124431872, 1.8788954244790634, 0.8516252547950416]
# ODE | z @ t=T | Float32[0.7230229, 1.1581715, 0.36365226]
# ODE | Input | Float32[0.38066703, 0.92237866, 0.0]
# ODE | z @ t=0 | Float32[0.23297112, 0.54257715, -0.0321095]
# ===========================
# ODE | Input | Float32[-0.72466063, -0.660289, 0.0]
# ODE | Ideal Before ReLU | [-1.2307677962305585, -1.471103900994589, -0.6585836430644673]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[-0.46315494, -0.27172625, 0.23630558]
# ODE | Input | Float32[-0.72466063, -0.660289, 0.0]
# ODE | z @ t=0 | Float32[-0.60577905, -0.5342323, -0.04230726]
# ===========================
# ODE | Input | Float32[0.21533997, 0.75379395, 0.0]
# ODE | Ideal Before ReLU | [0.7710898942071652, 1.490726503926099, 0.6675487772844072]
# ODE | Ideal ReLU | Val1 | [0.7710898942071652, 1.490726503926099, 0.6675487772844072]
# ODE | z @ t=T | Float32[0.5490429, 0.9776037, 0.34401724]
# ODE | Input | Float32[0.21533997, 0.75379395, 0.0]
# ODE | z @ t=0 | Float32[0.12261209, 0.45576182, -0.03200531]
# ===========================
# ODE | Input | Float32[-0.4317486, 0.5997425, 0.0]
# ODE | Ideal Before ReLU | [-0.20190860076028846, 0.8094753069965561, 0.2574223069513575]
# ODE | Ideal ReLU | Val1 | [0.0, 0.8094753069965561, 0.2574223069513575]
# ODE | z @ t=T | Float32[-0.25624478, 0.7173528, 0.30487618]
# ODE | Input | Float32[-0.4317486, 0.5997425, 0.0]
# ODE | z @ t=0 | Float32[-0.3828339, 0.43486, -0.024024773]
# ===========================
# ODE | Input | Float32[0.19858101, 0.32208788, 0.0]
# ODE | Ideal Before ReLU | [0.5344499478031518, 0.7644004282547827, 0.3944836076405368]
# ODE | Ideal ReLU | Val1 | [0.5344499478031518, 0.7644004282547827, 0.3944836076405368]
# ODE | z @ t=T | Float32[0.49123842, 0.60925967, 0.3172917]
# ODE | Input | Float32[0.19858101, 0.32208788, 0.0]
# ODE | z @ t=0 | Float32[0.109822124, 0.18186386, -0.033990547]
# ===========================
# ODE | Input | Float32[0.1664077, -0.36530545, 0.0]
# ODE | Ideal Before ReLU | [0.1500480114824994, -0.39572127220327846, -0.04298719463447004]
# ODE | Ideal ReLU | Val1 | [0.1500480114824994, 0.0, 0.0]
# ODE | z @ t=T | Float32[0.40845147, -0.09848776, 0.27978748]
# ODE | Input | Float32[0.1664077, -0.36530545, 0.0]
# ODE | z @ t=0 | Float32[0.09273694, -0.31238195, -0.033323538]
# ===========================
# ODE | Input | Float32[-0.9084468, -0.25225312, 0.0]
# ODE | Ideal Before ReLU | [-1.2837781184533437, -0.9160235820369776, -0.49785331994744075]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[-0.89352393, 0.071230076, 0.24673095]
# ODE | Input | Float32[-0.9084468, -0.25225312, 0.0]
# ODE | z @ t=0 | Float32[-0.7973544, -0.2357341, -0.029492583]
# ===========================
# ODE | Input | Float32[0.31260148, 0.9131035, 0.0]
# ODE | Ideal Before ReLU | [0.984645354605566, 1.8187172629616124, 0.8127367856536]
# ODE | Ideal ReLU | Val1 | [0.984645354605566, 1.8187172629616124, 0.8127367856536]
# ODE | z @ t=T | Float32[0.6597335, 1.1307732, 0.3593893]
# ODE | Input | Float32[0.31260148, 0.9131035, 0.0]
# ODE | z @ t=0 | Float32[0.18875597, 0.5432082, -0.031743612]
# ===========================
# ODE | Input | Float32[0.013465843, 0.8292968, 0.0]
# ODE | Ideal Before ReLU | [0.5286235589459019, 1.4829254825380365, 0.6154175389898675]
# ODE | Ideal ReLU | Val1 | [0.5286235589459019, 1.4829254825380365, 0.6154175389898675]
# ODE | z @ t=T | Float32[0.34374774, 0.98410374, 0.33870032]
# ODE | Input | Float32[0.013465843, 0.8292968, 0.0]
# ODE | z @ t=0 | Float32[-0.020483816, 0.5257996, -0.029608438]
# ===========================
# ODE | Input | Float32[0.3464005, 0.24156666, 0.0]
# ODE | Ideal Before ReLU | [0.6995175090363072, 0.7283002761036805, 0.417171787887718]
# ODE | Ideal ReLU | Val1 | [0.6995175090363072, 0.7283002761036805, 0.417171787887718]
# ODE | z @ t=T | Float32[0.60514337, 0.5565801, 0.31940916]
# ODE | Input | Float32[0.3464005, 0.24156666, 0.0]
# ODE | z @ t=0 | Float32[0.2133555, 0.1291187, -0.03393976]
# ===========================
# ODE | Input | Float32[0.053022064, -0.43855995, 0.0]
# ODE | Ideal Before ReLU | [-0.04331391587243849, -0.5917426895225354, -0.14323665564028637]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[0.3165713, -0.17170274, 0.272019]
# ODE | Input | Float32[0.053022064, -0.43855995, 0.0]
# ODE | z @ t=0 | Float32[0.006768905, -0.36886263, -0.03444057]
# ===========================
# ODE | Input | Float32[-0.3382327, 0.92553467, 0.0]
# ODE | Ideal Before ReLU | [0.08875575530639293, 1.4108449518607704, 0.5029358985755336]
# ODE | Ideal ReLU | Val1 | [0.08875575530639293, 1.4108449518607704, 0.5029358985755336]
# ODE | z @ t=T | Float32[-0.14097528, 0.96316165, 0.32757837]
# ODE | Input | Float32[-0.3382327, 0.92553467, 0.0]
# ODE | z @ t=0 | Float32[-0.30485094, 0.68879765, -0.02107765]
# ===========================
# ODE | Input | Float32[0.7476432, -0.6548307, 0.0]
# ODE | Ideal Before ReLU | [0.8124954648532553, -0.4927851955846456, 0.06284589568679838]
# ODE | Ideal ReLU | Val1 | [0.8124954648532553, 0.0, 0.06284589568679838]
# ODE | z @ t=T | Float32[0.7434172, -0.68869936, 0.28830796]
# ODE | Input | Float32[0.7476432, -0.6548307, 0.0]
# ODE | z @ t=0 | Float32[0.6380836, -0.6261099, -0.010074624]
# ===========================
# ODE | Input | Float32[0.40886217, 0.85643005, 0.0]
# ODE | Ideal Before ReLU | [1.0900431803330681, 1.7881872599549276, 0.8249112129191416]
# ODE | Ideal ReLU | Val1 | [1.0900431803330681, 1.7881872599549276, 0.8249112129191416]
# ODE | z @ t=T | Float32[0.7381855, 1.1132348, 0.36071712]
# ODE | Input | Float32[0.40886217, 0.85643005, 0.0]
# ODE | z @ t=0 | Float32[0.25095353, 0.50322515, -0.03253575]
# ===========================
# ODE | Input | Float32[-0.79148597, -0.11352927, 0.0]
# ODE | Ideal Before ReLU | [-1.0530965330114592, -0.6091724413570501, -0.355688682433668]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[-0.71874243, 0.17070189, 0.25647545]
# ODE | Input | Float32[-0.79148597, -0.11352927, 0.0]
# ODE | z @ t=0 | Float32[-0.69149846, -0.1222459, -0.029327778]
# ===========================
# ODE | Input | Float32[-0.52989346, 0.46521807, 0.0]
# ODE | Ideal Before ReLU | [-0.4044358950964717, 0.5219694884124901, 0.12701143990534633]
# ODE | Ideal ReLU | Val1 | [0.0, 0.5219694884124901, 0.12701143990534633]
# ODE | z @ t=T | Float32[-0.39975584, 0.60595626, 0.2936394]
# ODE | Input | Float32[-0.52989346, 0.46521807, 0.0]
# ODE | z @ t=0 | Float32[-0.46933004, 0.34054488, -0.023672193]
# ===========================
# ODE | Input | Float32[-0.23959911, 0.8174434, 0.0]
# ODE | Ideal Before ReLU | [0.17202408481964912, 1.296683010728082, 0.48471807773079256]
# ODE | Ideal ReLU | Val1 | [0.17202408481964912, 1.296683010728082, 0.48471807773079256]
# ODE | z @ t=T | Float32[0.019346187, 0.9123836, 0.325821]
# ODE | Input | Float32[-0.23959911, 0.8174434, 0.0]
# ODE | z @ t=0 | Float32[-0.21892819, 0.5664069, -0.025450705]
# ===========================
# ODE | Input | Float32[0.30099308, 0.8264141, 0.0]
# ODE | Ideal Before ReLU | [0.925701857655332, 1.6674394780267408, 0.7538831444702111]
# ODE | Ideal ReLU | Val1 | [0.925701857655332, 1.6674394780267408, 0.7538831444702111]
# ODE | z @ t=T | Float32[0.63793015, 1.0585649, 0.35305607]
# ODE | Input | Float32[0.30099308, 0.8264141, 0.0]
# ODE | z @ t=0 | Float32[0.18073016, 0.4932854, -0.032124154]
# ===========================
# ODE | Input | Float32[0.546632, -0.63202757, 0.0]
# ODE | Ideal Before ReLU | [0.5451731924558375, -0.5873362141997047, -0.021200601883122644]
# ODE | Ideal ReLU | Val1 | [0.5451731924558375, 0.0, 0.0]
# ODE | z @ t=T | Float32[0.63327676, -0.56696767, 0.2815142]
# ODE | Input | Float32[0.546632, -0.63202757, 0.0]
# ODE | z @ t=0 | Float32[0.43088922, -0.57557756, -0.01871115]
# ===========================
# ODE | Input | Float32[-0.6479357, 0.6162217, 0.0]
# ODE | Ideal Before ReLU | [-0.493390374576, 0.6944553820660361, 0.16209385046210603]
# ODE | Ideal ReLU | Val1 | [0.0, 0.6944553820660361, 0.16209385046210603]
# ODE | z @ t=T | Float32[-0.667097, 0.68813306, 0.2966087]
# ODE | Input | Float32[-0.6479357, 0.6162217, 0.0]
# ODE | z @ t=0 | Float32[-0.59301627, 0.52203476, -0.014912588]
# ===========================
# ODE | Input | Float32[0.19706498, -0.929805, 0.0]
# ODE | Ideal Before ReLU | [-0.08652061305643324, -1.310856627253548, -0.3744072493733619]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[0.3892987, -0.9397084, 0.25516322]
# ODE | Input | Float32[0.19706498, -0.929805, 0.0]
# ODE | z @ t=0 | Float32[0.14577372, -0.84450203, -0.019477716]
# ===========================
# ODE | Input | Float32[-0.75666136, 0.25542736, 0.0]
# ODE | Ideal Before ReLU | [-0.822438183153248, 0.025077523112832095, -0.11231498656356023]
# ODE | Ideal ReLU | Val1 | [0.0, 0.025077523112832095, 0.0]
# ODE | z @ t=T | Float32[-0.7785105, 0.43119895, 0.27438456]
# ODE | Input | Float32[-0.75666136, 0.25542736, 0.0]
# ODE | z @ t=0 | Float32[-0.68240273, 0.19576329, -0.019985424]
# ===========================
# ODE | Input | Float32[-0.09490639, -0.12782365, 0.0]
# ODE | Ideal Before ReLU | [-0.09472638437019723, -0.17427134093032817, -0.024719853210315335]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[0.1990047, 0.16693878, 0.2812344]
# ODE | Input | Float32[-0.09490639, -0.12782365, 0.0]
# ODE | z @ t=0 | Float32[-0.106122695, -0.13160263, -0.036019653]
# ===========================
# ODE | Input | Float32[0.7081733, -0.36639437, 0.0]
# ODE | Ideal Before ReLU | [0.9003790871308902, -0.040860148627075626, 0.22057763452902035]
# ODE | Ideal ReLU | Val1 | [0.9003790871308902, 0.0, 0.22057763452902035]
# ODE | z @ t=T | Float32[0.7647456, -0.16785885, 0.30164582]
# ODE | Input | Float32[0.7081733, -0.36639437, 0.0]
# ODE | z @ t=0 | Float32[0.52573085, -0.32865614, -0.023494406]
# ===========================
# ODE | Input | Float32[0.17832279, -0.16155265, 0.0]
# ODE | Ideal Before ReLU | [0.26728650519199393, -0.05027946402380909, 0.0878451887995199]
# ODE | Ideal ReLU | Val1 | [0.26728650519199393, 0.0, 0.0878451887995199]
# ODE | z @ t=T | Float32[0.4331323, 0.13280055, 0.29037]
# ODE | Input | Float32[0.17832279, -0.16155265, 0.0]
# ODE | z @ t=0 | Float32[0.09824681, -0.15525742, -0.034308877]
# ===========================
# ODE | Input | Float32[-0.29030713, -0.72877944, 0.0]
# ODE | Ideal Before ReLU | [-0.6626260785246137, -1.298633790085172, -0.4887634773532584]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[0.023707481, -0.44153497, 0.24733897]
# ODE | Input | Float32[-0.29030713, -0.72877944, 0.0]
# ODE | z @ t=0 | Float32[-0.25959456, -0.59326756, -0.0386972]
# ===========================
# ODE | Input | Float32[0.2254207, 0.14831229, 0.0]
# ODE | Ideal Before ReLU | [0.4857434454444226, 0.49414156844076296, 0.30094669533301244]
# ODE | Ideal ReLU | Val1 | [0.4857434454444226, 0.49414156844076296, 0.30094669533301244]
# ODE | z @ t=T | Float32[0.49787402, 0.45133403, 0.30874988]
# ODE | Input | Float32[0.2254207, 0.14831229, 0.0]
# ODE | z @ t=0 | Float32[0.12941566, 0.06557243, -0.034332335]
# ===========================
# ODE | Input | Float32[0.65603685, -0.46959013, 0.0]
# ODE | Ideal Before ReLU | [0.7771052054555381, -0.2461684429054408, 0.13182927210814233]
# ODE | Ideal ReLU | Val1 | [0.7771052054555381, 0.0, 0.13182927210814233]
# ODE | z @ t=T | Float32[0.71914417, -0.32247627, 0.29404482]
# ODE | Input | Float32[0.65603685, -0.46959013, 0.0]
# ODE | z @ t=0 | Float32[0.49969235, -0.42231065, -0.021555757]
# ===========================
# ODE | Input | Float32[-0.68679243, 0.33396992, 0.0]
# ODE | Ideal Before ReLU | [-0.6867748663786017, 0.2012119767215567, -0.0300450321848989]
# ODE | Ideal ReLU | Val1 | [0.0, 0.2012119767215567, 0.0]
# ODE | z @ t=T | Float32[-0.66055304, 0.49279556, 0.28081158]
# ODE | Input | Float32[-0.68679243, 0.33396992, 0.0]
# ODE | z @ t=0 | Float32[-0.615873, 0.25520614, -0.020925032]
# ===========================
# ODE | Input | Float32[-0.10084318, -0.81946737, 0.0]
# ODE | Ideal Before ReLU | [-0.44486653369365003, -1.3241629677088689, -0.4520024325972344]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[0.18384762, -0.6195515, 0.24981856]
# ODE | Input | Float32[-0.10084318, -0.81946737, 0.0]
# ODE | z @ t=0 | Float32[-0.11149573, -0.68688303, -0.03359375]
# ===========================
# ODE | Input | Float32[0.85681164, -0.33616948, 0.0]
# ODE | Ideal Before ReLU | [1.1213285892237055, 0.10707383456685857, 0.31161813362620916]
# ODE | Ideal ReLU | Val1 | [1.1213285892237055, 0.10707383456685857, 0.31161813362620916]
# ODE | z @ t=T | Float32[0.85380965, -0.1406634, 0.30970934]
# ODE | Input | Float32[0.85681164, -0.33616948, 0.0]
# ODE | z @ t=0 | Float32[0.6474834, -0.30646184, -0.021181414]
# ===========================
# ODE | Input | Float32[0.3519628, -0.73237646, 0.0]
# ODE | Ideal Before ReLU | [0.2257608944777421, -0.8817624039798267, -0.17771903939616576]
# ODE | Ideal ReLU | Val1 | [0.2257608944777421, 0.0, 0.0]
# ODE | z @ t=T | Float32[0.50402784, -0.66651636, 0.26941273]
# ODE | Input | Float32[0.3519628, -0.73237646, 0.0]
# ODE | z @ t=0 | Float32[0.26679403, -0.65649533, -0.021455593]
# ===========================
# ODE | Input | Float32[-0.3145495, -0.08332329, 0.0]
# ODE | Ideal Before ReLU | [-0.3771459506926246, -0.24513838547319247, -0.10454037675276273]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[-0.030725542, 0.20377414, 0.27498356]
# ODE | Input | Float32[-0.3145495, -0.08332329, 0.0]
# ODE | z @ t=0 | Float32[-0.27635607, -0.10007973, -0.035756372]
# ===========================
# ODE | Input | Float32[-0.33123642, -0.029787919, 0.0]
# ODE | Ideal Before ReLU | [-0.37380842380139057, -0.16742136866400312, -0.07983013703742278]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[-0.05342879, 0.24893214, 0.27689892]
# ODE | Input | Float32[-0.33123642, -0.029787919, 0.0]
# ODE | z @ t=0 | Float32[-0.28986344, -0.060877442, -0.03511598]
# ===========================
# ODE | Input | Float32[-0.4897657, -0.052393127, 0.0]
# ODE | Ideal Before ReLU | [-0.6046996436323858, -0.3092418900318492, -0.17101931362195436]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[-0.25253934, 0.22445485, 0.26991653]
# ODE | Input | Float32[-0.4897657, -0.052393127, 0.0]
# ODE | z @ t=0 | Float32[-0.42040613, -0.07688224, -0.034102395]
# ===========================
# ODE | Input | Float32[-0.2949378, -0.13432252, 0.0]
# ODE | Ideal Before ReLU | [-0.3751760663328422, -0.3167277632873665, -0.12626795984504152]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[-0.0059357476, 0.15944843, 0.27331373]
# ODE | Input | Float32[-0.2949378, -0.13432252, 0.0]
# ODE | z @ t=0 | Float32[-0.26073858, -0.13733605, -0.036290567]
# ===========================
# ODE | Input | Float32[0.07535612, -0.8235714, 0.0]
# ODE | Ideal Before ReLU | [-0.20268886718309112, -1.2149640536627322, -0.36858370134052887]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[0.3139929, -0.69775546, 0.2555705]
# ODE | Input | Float32[0.07535612, -0.8235714, 0.0]
# ODE | z @ t=0 | Float32[0.032546528, -0.7119654, -0.028113354]
# ===========================
# ODE | Input | Float32[-0.47364405, 0.6251188, 0.0]
# ODE | Ideal Before ReLU | [-0.24742961853124248, 0.8239398811144814, 0.2525595275692476]
# ODE | Ideal ReLU | Val1 | [0.0, 0.8239398811144814, 0.2525595275692476]
# ODE | z @ t=T | Float32[-0.33098269, 0.72695065, 0.3044472]
# ODE | Input | Float32[-0.47364405, 0.6251188, 0.0]
# ODE | z @ t=0 | Float32[-0.42182633, 0.46789554, -0.022214808]
# ===========================
# ODE | Input | Float32[0.32700935, 0.71945405, 0.0]
# ODE | Ideal Before ReLU | [0.9088841747005879, 1.507345072812341, 0.7009421086438588]
# ODE | Ideal ReLU | Val1 | [0.9088841747005879, 1.507345072812341, 0.7009421086438588]
# ODE | z @ t=T | Float32[0.64786994, 0.9783818, 0.34747836]
# ODE | Input | Float32[0.32700935, 0.71945405, 0.0]
# ODE | z @ t=0 | Float32[0.19771226, 0.42814192, -0.032755073]
# ===========================
# ODE | Input | Float32[0.5433472, -0.47519088, 0.0]
# ODE | Ideal Before ReLU | [0.6181522858125874, -0.32963631175811814, 0.0734310488519107]
# ODE | Ideal ReLU | Val1 | [0.6181522858125874, 0.0, 0.0734310488519107]
# ODE | z @ t=T | Float32[0.6513802, -0.30693603, 0.28917867]
# ODE | Input | Float32[0.5433472, -0.47519088, 0.0]
# ODE | z @ t=0 | Float32[0.40238243, -0.42075783, -0.02420795]
# ===========================
# ODE | Input | Float32[-0.12495949, 0.3032802, 0.0]
# ODE | Ideal Before ReLU | [0.0767358662203091, 0.5202387216999228, 0.22514435570191213]
# ODE | Ideal ReLU | Val1 | [0.0767358662203091, 0.5202387216999228, 0.22514435570191213]
# ODE | z @ t=T | Float32[0.17288806, 0.54470676, 0.3020438]
# ODE | Input | Float32[-0.12495949, 0.3032802, 0.0]
# ODE | z @ t=0 | Float32[-0.1276063, 0.17513344, -0.033062648]
# ===========================
# ODE | Input | Float32[-0.13953133, 0.83970654, 0.0]
# ODE | Ideal Before ReLU | [0.3217204867339246, 1.3994493267428258, 0.5471842059041204]
# ODE | Ideal ReLU | Val1 | [0.3217204867339246, 1.3994493267428258, 0.5471842059041204]
# ODE | z @ t=T | Float32[0.1565278, 0.9528883, 0.33189738]
# ODE | Input | Float32[-0.13953133, 0.83970654, 0.0]
# ODE | z @ t=0 | Float32[-0.13761681, 0.5601531, -0.027197298]
# ===========================
# ODE | Input | Float32[0.21447366, 0.69002026, 0.0]
# ODE | Ideal Before ReLU | [0.7383628898463616, 1.3844896662498156, 0.6279952290212187]
# ODE | Ideal ReLU | Val1 | [0.7383628898463616, 1.3844896662498156, 0.6279952290212187]
# ODE | z @ t=T | Float32[0.54158634, 0.9260088, 0.33997357]
# ODE | Input | Float32[0.21447366, 0.69002026, 0.0]
# ODE | z @ t=0 | Float32[0.1216918, 0.4163418, -0.032364868]
# ===========================
# ODE | Input | Float32[0.104513146, 0.16223446, 0.0]
# ODE | Ideal Before ReLU | [0.32505191021169433, 0.4376110412274913, 0.2505195093929092]
# ODE | Ideal ReLU | Val1 | [0.32505191021169433, 0.4376110412274913, 0.2505195093929092]
# ODE | z @ t=T | Float32[0.3951463, 0.45121568, 0.30426756]
# ODE | Input | Float32[0.104513146, 0.16223446, 0.0]
# ODE | z @ t=0 | Float32[0.042565145, 0.074563704, -0.034542378]
# ===========================
# ODE | Input | Float32[0.9361763, 0.04137134, 0.0]
# ODE | Ideal Before ReLU | [1.4179615578076714, 0.7848693738596807, 0.581982344854096]
# ODE | Ideal ReLU | Val1 | [1.4179615578076714, 0.7848693738596807, 0.581982344854096]
# ODE | z @ t=T | Float32[0.9663571, 0.4032335, 0.335345]
# ODE | Input | Float32[0.9361763, 0.04137134, 0.0]
# ODE | z @ t=0 | Float32[0.6348444, 0.002202198, -0.028531104]
# ===========================
# ODE | Input | Float32[-0.09510688, 0.9347065, 0.0]
# ODE | Ideal Before ReLU | [0.4302542684587237, 1.5861009460670503, 0.6271423730910918]
# ODE | Ideal ReLU | Val1 | [0.4302542684587237, 1.5861009460670503, 0.6271423730910918]
# ODE | z @ t=T | Float32[0.2151965, 1.0328985, 0.33988705]
# ODE | Input | Float32[-0.09510688, 0.9347065, 0.0]
# ODE | z @ t=0 | Float32[-0.102375574, 0.6197683, -0.026900865]
# ===========================
# ODE | Input | Float32[0.113648005, -0.27549228, 0.0]
# ODE | Ideal Before ReLU | [0.12132365810354234, -0.2816437530960474, -0.013610810217385305]
# ODE | Ideal ReLU | Val1 | [0.12132365810354234, 0.0, 0.0]
# ODE | z @ t=T | Float32[0.37384987, 0.009690624, 0.28211907]
# ODE | Input | Float32[0.113648005, -0.27549228, 0.0]
# ODE | z @ t=0 | Float32[0.051247295, -0.241346, -0.03453131]
# ===========================
# ODE | Input | Float32[0.60449106, 0.41242206, 0.0]
# ODE | Ideal Before ReLU | [1.1416844298576931, 1.1813013322199755, 0.6478846880020521]
# ODE | Ideal ReLU | Val1 | [1.1416844298576931, 1.1813013322199755, 0.6478846880020521]
# ODE | z @ t=T | Float32[0.82161725, 0.76748604, 0.34199932]
# ODE | Input | Float32[0.60449106, 0.41242206, 0.0]
# ODE | z @ t=0 | Float32[0.38194484, 0.24050315, -0.033387262]
# ===========================
# ODE | Input | Float32[0.72070265, -0.09967505, 0.0]
# ODE | Ideal Before ReLU | [1.0495962653217272, 0.409315176084565, 0.39034537273672065]
# ODE | Ideal ReLU | Val1 | [1.0495962653217272, 0.409315176084565, 0.39034537273672065]
# ODE | z @ t=T | Float32[0.81422234, 0.20885532, 0.31690738]
# ODE | Input | Float32[0.72070265, -0.09967505, 0.0]
# ODE | z @ t=0 | Float32[0.49656868, -0.106337726, -0.028881202]
# ===========================
# ODE | Input | Float32[-0.81334484, -0.20523556, 0.0]
# ODE | Ideal Before ReLU | [-1.1287269335690624, -0.7755109593601753, -0.4226200572273856]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[-0.7281328, 0.103654996, 0.25182453]
# ODE | Input | Float32[-0.81334484, -0.20523556, 0.0]
# ODE | z @ t=0 | Float32[-0.7066255, -0.19575891, -0.031183552]
# ===========================
# ODE | Input | Float32[0.11669028, 0.9015783, 0.0]
# ODE | Ideal Before ReLU | [0.7074213804374955, 1.6706451947627512, 0.7101140844549025]
# ODE | Ideal ReLU | Val1 | [0.7074213804374955, 1.6706451947627512, 0.7101140844549025]
# ODE | z @ t=T | Float32[0.46293676, 1.0662166, 0.3484367]
# ODE | Input | Float32[0.11669028, 0.9015783, 0.0]
# ODE | z @ t=0 | Float32[0.054896068, 0.5585425, -0.030175084]
# ===========================
# ODE | Input | Float32[-0.7510322, 0.18934567, 0.0]
# ODE | Ideal Before ReLU | [-0.8473036004995219, -0.08070719499549742, -0.15011668522114055]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[-0.74326855, 0.38663772, 0.27149633]
# ODE | Input | Float32[-0.7510322, 0.18934567, 0.0]
# ODE | z @ t=0 | Float32[-0.67180103, 0.1337924, -0.022229526]
# ===========================
# ODE | Input | Float32[0.004003625, 0.8707618, 0.0]
# ODE | Ideal Before ReLU | [0.5360073213431563, 1.545399392925956, 0.6362451550241642]
# ODE | Ideal ReLU | Val1 | [0.5360073213431563, 1.545399392925956, 0.6362451550241642]
# ODE | z @ t=T | Float32[0.33493257, 1.0126011, 0.34081197]
# ODE | Input | Float32[0.004003625, 0.8707618, 0.0]
# ODE | z @ t=0 | Float32[-0.027219582, 0.555278, -0.029105145]
# ===========================
# ODE | Input | Float32[-0.7453749, -0.037503418, 0.0]
# ODE | Ideal Before ReLU | [-0.95160498030114, -0.4528486457688209, -0.2865502841182711]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[-0.6581671, 0.2269778, 0.26140103]
# ODE | Input | Float32[-0.7453749, -0.037503418, 0.0]
# ODE | z @ t=0 | Float32[-0.6514673, -0.061215337, -0.028719844]
# ===========================
# ODE | Input | Float32[-0.7763634, 0.28883243, 0.0]
# ODE | Ideal Before ReLU | [-0.8332308437901254, 0.06745571065729469, -0.10142708522734031]
# ODE | Ideal ReLU | Val1 | [0.0, 0.06745571065729469, 0.0]
# ODE | z @ t=T | Float32[-0.833934, 0.451532, 0.2752239]
# ODE | Input | Float32[-0.7763634, 0.28883243, 0.0]
# ODE | z @ t=0 | Float32[-0.70582825, 0.23202592, -0.01791945]
# ===========================
# ODE | Input | Float32[0.37075338, -0.22688462, 0.0]
# ODE | Ideal Before ReLU | [0.5016923524943255, -0.03184333868054215, 0.14161135488189258]
# ODE | Ideal ReLU | Val1 | [0.5016923524943255, 0.0, 0.14161135488189258]
# ODE | z @ t=T | Float32[0.5691925, 0.053287745, 0.29487038]
# ODE | Input | Float32[0.37075338, -0.22688462, 0.0]
# ODE | z @ t=0 | Float32[0.24366802, -0.2051946, -0.031785987]
# ===========================
# ODE | Input | Float32[0.5023934, 0.69442564, 0.0]
# ODE | Ideal Before ReLU | [1.1395880547215878, 1.5813377083924975, 0.77112419446911]
# ODE | Ideal ReLU | Val1 | [1.1395880547215878, 1.5813377083924975, 0.77112419446911]
# ODE | z @ t=T | Float32[0.7907151, 1.0028259, 0.35489675]
# ODE | Input | Float32[0.5023934, 0.69442564, 0.0]
# ODE | z @ t=0 | Float32[0.31106177, 0.40723205, -0.0333231]
# ===========================
# ODE | Input | Float32[-0.83939487, 0.23628002, 0.0]
# ODE | Ideal Before ReLU | [-0.9465695543384937, -0.06111435267710516, -0.16441489728202682]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[-0.9563277, 0.40980273, 0.27041438]
# ODE | Input | Float32[-0.83939487, 0.23628002, 0.0]
# ODE | z @ t=0 | Float32[-0.7698226, 0.19459382, -0.01608886]
# ===========================
# ODE | Input | Float32[0.18571848, -0.08710348, 0.0]
# ODE | Ideal Before ReLU | [0.3143404031879785, 0.07794410311293146, 0.13713367201623175]
# ODE | Ideal ReLU | Val1 | [0.3143404031879785, 0.07794410311293146, 0.13713367201623175]
# ODE | z @ t=T | Float32[0.44497338, 0.21219523, 0.2944921]
# ODE | Input | Float32[0.18571848, -0.08710348, 0.0]
# ODE | z @ t=0 | Float32[0.10279963, -0.10044493, -0.034439027]
# ===========================
# ODE | Input | Float32[-0.51215416, 0.75435996, 0.0]
# ODE | Ideal Before ReLU | [-0.2369134033152224, 1.0127266305042557, 0.31307850361648276]
# ODE | Ideal ReLU | Val1 | [0.0, 1.0127266305042557, 0.31307850361648276]
# ODE | z @ t=T | Float32[-0.42574048, 0.8069275, 0.309841]
# ODE | Input | Float32[-0.51215416, 0.75435996, 0.0]
# ODE | z @ t=0 | Float32[-0.46262148, 0.6024906, -0.017967094]
# ===========================
# ODE | Input | Float32[-0.07456405, 0.81034094, 0.0]
# ODE | Ideal Before ReLU | [0.3972462231424878, 1.3935640081843585, 0.5608519207907885]
# ODE | Ideal ReLU | Val1 | [0.3972462231424878, 1.3935640081843585, 0.5608519207907885]
# ODE | z @ t=T | Float32[0.23873726, 0.94766635, 0.33324608]
# ODE | Input | Float32[-0.07456405, 0.81034094, 0.0]
# ODE | z @ t=0 | Float32[-0.0869889, 0.52661115, -0.02859882]
# ===========================
# ODE | Input | Float32[0.735216, 0.11802974, 0.0]
# ODE | Ideal Before ReLU | [1.1773330237095818, 0.7795845708877305, 0.5310058390529809]
# ODE | Ideal ReLU | Val1 | [1.1773330237095818, 0.7795845708877305, 0.5310058390529809]
# ODE | z @ t=T | Float32[0.8595004, 0.47643656, 0.33030996]
# ODE | Input | Float32[0.735216, 0.11802974, 0.0]
# ODE | z @ t=0 | Float32[0.48521486, 0.052410915, -0.031282127]
# ===========================
# ODE | Input | Float32[-0.08033233, -0.78340125, 0.0]
# ODE | Ideal Before ReLU | [-0.3986099893880398, -1.250901996069504, -0.4198688835513631]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[0.20038599, -0.57751095, 0.25201344]
# ODE | Input | Float32[-0.08033233, -0.78340125, 0.0]
# ODE | z @ t=0 | Float32[-0.09522834, -0.6560682, -0.033581823]
# ===========================
# ODE | Input | Float32[0.16080044, 0.39585423, 0.0]
# ODE | Ideal Before ReLU | [0.5185534840419842, 0.8617513421978183, 0.42131949742981334]
# ODE | Ideal ReLU | Val1 | [0.5185534840419842, 0.8617513421978183, 0.42131949742981334]
# ODE | z @ t=T | Float32[0.46397862, 0.6680216, 0.31979817]
# ODE | Input | Float32[0.16080044, 0.39585423, 0.0]
# ODE | z @ t=0 | Float32[0.083216205, 0.23071162, -0.03365505]
# ===========================
# ODE | Input | Float32[-0.5565322, -0.56034625, 0.0]
# ODE | Ideal Before ReLU | [-0.9483408962062497, -1.194823466057386, -0.5152590218357451]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[-0.26742065, -0.2091515, 0.24557228]
# ODE | Input | Float32[-0.5565322, -0.56034625, 0.0]
# ODE | z @ t=0 | Float32[-0.4687947, -0.45659465, -0.040743437]
# ===========================
# ODE | Input | Float32[0.15772422, 0.08079907, 0.0]
# ODE | Ideal Before ReLU | [0.35854338413656306, 0.33771182290849355, 0.22650381546375922]
# ODE | Ideal ReLU | Val1 | [0.35854338413656306, 0.33771182290849355, 0.22650381546375922]
# ODE | z @ t=T | Float32[0.43545622, 0.37958723, 0.30216235]
# ODE | Input | Float32[0.15772422, 0.08079907, 0.0]
# ODE | z @ t=0 | Float32[0.08120507, 0.018603494, -0.034620162]
# ===========================
# ODE | Input | Float32[0.62215555, -0.40613815, 0.0]
# ODE | Ideal Before ReLU | [0.7615141108311063, -0.163340362853615, 0.15423811366710338]
# ODE | Ideal ReLU | Val1 | [0.7615141108311063, 0.0, 0.15423811366710338]
# ODE | z @ t=T | Float32[0.7082413, -0.21558598, 0.29594043]
# ODE | Input | Float32[0.62215555, -0.40613815, 0.0]
# ODE | z @ t=0 | Float32[0.4593981, -0.3612201, -0.024278792]
# ===========================
# ODE | Input | Float32[0.49964052, -0.8331868, 0.0]
# ODE | Ideal Before ReLU | [0.38060210192326394, -0.9515728994370775, -0.16754924750664255]
# ODE | Ideal ReLU | Val1 | [0.38060210192326394, 0.0, 0.0]
# ODE | z @ t=T | Float32[0.5817289, -0.92950284, 0.270178]
# ODE | Input | Float32[0.49964052, -0.8331868, 0.0]
# ODE | z @ t=0 | Float32[0.42843583, -0.79447883, -0.010116463]
# ===========================
# ODE | Input | Float32[0.43352318, 0.19283406, 0.0]
# ODE | Ideal Before ReLU | [0.7961758869868935, 0.7049115792336517, 0.42976182566399745]
# ODE | Ideal ReLU | Val1 | [0.7961758869868935, 0.7049115792336517, 0.42976182566399745]
# ODE | z @ t=T | Float32[0.66536736, 0.5202621, 0.32059196]
# ODE | Input | Float32[0.43352318, 0.19283406, 0.0]
# ODE | z @ t=0 | Float32[0.27435365, 0.097737856, -0.033573423]
# ===========================
# ODE | Input | Float32[-0.0702905, 0.42265397, 0.0]
# ODE | Ideal Before ReLU | [0.2115173598243617, 0.7540196246185727, 0.3250546170260431]
# ODE | Ideal ReLU | Val1 | [0.2115173598243617, 0.7540196246185727, 0.3250546170260431]
# ODE | z @ t=T | Float32[0.23471555, 0.6501977, 0.31092292]
# ODE | Input | Float32[-0.0702905, 0.42265397, 0.0]
# ODE | z @ t=0 | Float32[-0.085490994, 0.25614086, -0.03240314]
# ===========================
# ODE | Input | Float32[0.43706354, -0.14237249, 0.0]
# ODE | Ideal Before ReLU | [0.6353743893812277, 0.15183921622246443, 0.22580849295929484]
# ODE | Ideal ReLU | Val1 | [0.6353743893812277, 0.15183921622246443, 0.22580849295929484]
# ODE | z @ t=T | Float32[0.6249926, 0.15342039, 0.3021017]
# ODE | Input | Float32[0.43706354, -0.14237249, 0.0]
# ODE | z @ t=0 | Float32[0.2891798, -0.14018726, -0.031787664]
# ===========================
# ODE | Input | Float32[-0.22908399, -0.8810349, 0.0]
# ODE | Ideal Before ReLU | [-0.6530398209213665, -1.5106000279732648, -0.5523261175922686]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[0.08087393, -0.6525272, 0.2431292]
# ODE | Input | Float32[-0.22908399, -0.8810349, 0.0]
# ODE | z @ t=0 | Float32[-0.21339372, -0.72907436, -0.036286622]
# ===========================
# ODE | Input | Float32[-0.17881896, 0.43499443, 0.0]
# ODE | Ideal Before ReLU | [0.06720093047253609, 0.703017998838717, 0.27969450677347263]
# ODE | Ideal ReLU | Val1 | [0.06720093047253609, 0.703017998838717, 0.27969450677347263]
# ODE | z @ t=T | Float32[0.11030357, 0.64145494, 0.3068505]
# ODE | Input | Float32[-0.17881896, 0.43499443, 0.0]
# ODE | z @ t=0 | Float32[-0.169174, 0.27142453, -0.031267334]
# ===========================
# ODE | Input | Float32[0.46012434, -0.85817534, 0.0]
# ODE | Ideal Before ReLU | [0.31348096249951063, -1.0189913913257287, -0.20215506699123634]
# ODE | Ideal ReLU | Val1 | [0.31348096249951063, 0.0, 0.0]
# ODE | z @ t=T | Float32[0.55613, -0.9577281, 0.2675858]
# ODE | Input | Float32[0.46012434, -0.85817534, 0.0]
# ODE | z @ t=0 | Float32[0.3929904, -0.81647563, -0.010510298]
# ===========================
# ODE | Input | Float32[-0.030361189, 0.4695024, 0.0]
# ODE | Ideal Before ReLU | [0.29001744935680396, 0.8579296976616272, 0.3732749803576614]
# ODE | Ideal ReLU | Val1 | [0.29001744935680396, 0.8579296976616272, 0.3732749803576614]
# ODE | z @ t=T | Float32[0.27936545, 0.69504166, 0.3153286]
# ODE | Input | Float32[-0.030361189, 0.4695024, 0.0]
# ODE | z @ t=0 | Float32[-0.055242676, 0.28628188, -0.03230719]
# ===========================
# ODE | Input | Float32[-0.92852145, 0.051624592, 0.0]
# ODE | Ideal Before ReLU | [-1.1613799372391775, -0.42574509814987305, -0.3211873184937889]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[-1.0811703, 0.28031915, 0.25891784]
# ODE | Input | Float32[-0.92852145, 0.051624592, 0.0]
# ODE | z @ t=0 | Float32[-0.850137, 0.029159265, -0.017556183]
# ===========================
# ODE | Input | Float32[-0.11037983, 0.2385389, 0.0]
# ODE | Ideal Before ReLU | [0.06493813807490781, 0.42256734078263025, 0.1925304877664392]
# ODE | Ideal ReLU | Val1 | [0.06493813807490781, 0.42256734078263025, 0.1925304877664392]
# ODE | z @ t=T | Float32[0.18820532, 0.49302298, 0.29921642]
# ODE | Input | Float32[-0.11037983, 0.2385389, 0.0]
# ODE | z @ t=0 | Float32[-0.116662264, 0.1292497, -0.03370467]
# ===========================
# ODE | Input | Float32[0.86900026, -0.013872632, 0.0]
# ODE | Ideal Before ReLU | [1.2975480671005184, 0.6491111324065119, 0.5153216028391366]
# ODE | Ideal ReLU | Val1 | [1.2975480671005184, 0.6491111324065119, 0.5153216028391366]
# ODE | z @ t=T | Float32[0.9172665, 0.32646716, 0.32878017]
# ODE | Input | Float32[0.86900026, -0.013872632, 0.0]
# ODE | z @ t=0 | Float32[0.5947788, -0.039676357, -0.028416764]
# ===========================
# ODE | Input | Float32[0.22932234, 0.7642263, 0.0]
# ODE | Ideal Before ReLU | [0.7956262092344563, 1.51721700471669, 0.6807695526489836]
# ODE | Ideal ReLU | Val1 | [0.7956262092344563, 1.51721700471669, 0.6807695526489836]
# ODE | z @ t=T | Float32[0.5635327, 0.98956126, 0.34538227]
# ODE | Input | Float32[0.22932234, 0.7642263, 0.0]
# ODE | z @ t=0 | Float32[0.13223058, 0.46114314, -0.032032657]
# ===========================
# ODE | Input | Float32[-0.7244583, -0.4270563, 0.0]
# ODE | Ideal Before ReLU | [-1.1151894772227984, -1.0845278857132352, -0.5153752425064556]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[-0.51685303, -0.07260017, 0.24556457]
# ODE | Input | Float32[-0.7244583, -0.4270563, 0.0]
# ODE | z @ t=0 | Float32[-0.61316836, -0.36186156, -0.038085926]
# ===========================
# ODE | Input | Float32[0.14701329, -0.8323592, 0.0]
# ODE | Ideal Before ReLU | [-0.107718593648542, -1.1823498567797341, -0.3390267883488095]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[0.36283854, -0.74395126, 0.2576511]
# ODE | Input | Float32[0.14701329, -0.8323592, 0.0]
# ODE | z @ t=0 | Float32[0.09397042, -0.73094213, -0.025349984]
# ===========================
# ODE | Input | Float32[-0.30678862, 0.108336136, 0.0]
# ODE | Ideal Before ReLU | [-0.2716433714545814, 0.07753106077236577, 0.01684549732993955]
# ODE | Ideal ReLU | Val1 | [0.0, 0.07753106077236577, 0.01684549732993955]
# ODE | z @ t=T | Float32[-0.03264029, 0.3650096, 0.28456336]
# ODE | Input | Float32[-0.30678862, 0.108336136, 0.0]
# ODE | z @ t=0 | Float32[-0.27071673, 0.039997745, -0.03371049]
# ===========================
# ODE | Input | Float32[0.35885265, -0.65480787, 0.0]
# ODE | Ideal Before ReLU | [0.2736557959306589, -0.7487032920365299, -0.12676321576838462]
# ODE | Ideal ReLU | Val1 | [0.2736557959306589, 0.0, 0.0]
# ODE | z @ t=T | Float32[0.516031, -0.54021084, 0.27327585]
# ODE | Input | Float32[0.35885265, -0.65480787, 0.0]
# ODE | z @ t=0 | Float32[0.26431385, -0.5785803, -0.023910483]
# ===========================
# ODE | Input | Float32[0.4268053, 0.8032232, 0.0]
# ODE | Ideal Before ReLU | [1.0886091017196904, 1.7118415593087517, 0.8010152259391907]
# ODE | Ideal ReLU | Val1 | [1.0886091017196904, 1.7118415593087517, 0.8010152259391907]
# ODE | z @ t=T | Float32[0.7456512, 1.0745854, 0.3581166]
# ODE | Input | Float32[0.4268053, 0.8032232, 0.0]
# ODE | z @ t=0 | Float32[0.26247957, 0.47200587, -0.032811295]
# ===========================
# ODE | Input | Float32[-0.4345872, 0.09144355, 0.0]
# ODE | Ideal Before ReLU | [-0.45711883342737714, -0.0345930086443037, -0.055850308499493656]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[-0.19548093, 0.341408, 0.2787745]
# ODE | Input | Float32[-0.4345872, 0.09144355, 0.0]
# ODE | z @ t=0 | Float32[-0.3759671, 0.030566718, -0.032581918]
# ===========================
# ODE | Input | Float32[-0.70624995, 0.2806783, 0.0]
# ODE | Ideal Before ReLU | [-0.7400869001473406, 0.10010354945793412, -0.07223427499881532]
# ODE | Ideal ReLU | Val1 | [0.0, 0.10010354945793412, 0.0]
# ODE | z @ t=T | Float32[-0.6829198, 0.4539845, 0.2774912]
# ODE | Input | Float32[-0.70624995, 0.2806783, 0.0]
# ODE | z @ t=0 | Float32[-0.63227874, 0.20980711, -0.021558644]
# ===========================
# ODE | Input | Float32[0.019251993, -0.35587707, 0.0]
# ODE | Ideal Before ReLU | [-0.04924410454408057, -0.4769777323197444, -0.10897363396562798]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[0.29316708, -0.07274761, 0.27464175]
# ODE | Input | Float32[0.019251993, -0.35587707, 0.0]
# ODE | z @ t=0 | Float32[-0.019672105, -0.3027293, -0.03529724]
# ===========================
# ODE | Input | Float32[-0.10827491, -0.70622945, 0.0]
# ODE | Ideal Before ReLU | [-0.3991878423897144, -1.1414318621878388, -0.38614519423210547]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[0.17940243, -0.4662843, 0.25434494]
# ODE | Input | Float32[-0.10827491, -0.70622945, 0.0]
# ODE | z @ t=0 | Float32[-0.1174588, -0.5853945, -0.035196185]
# ===========================
# ODE | Input | Float32[0.17921825, -0.0405786, 0.0]
# ODE | Ideal Before ReLU | [0.32833072874133007, 0.15075173548101037, 0.1625106367580953]
# ODE | Ideal ReLU | Val1 | [0.32833072874133007, 0.15075173548101037, 0.1625106367580953]
# ODE | z @ t=T | Float32[0.44353822, 0.2602064, 0.29664415]
# ODE | Input | Float32[0.17921825, -0.0405786, 0.0]
# ODE | z @ t=0 | Float32[0.097576946, -0.06688761, -0.034548156]
# ===========================
# ODE | Input | Float32[-0.14537819, 0.36940807, 0.0]
# ODE | Ideal Before ReLU | [0.08112632837473949, 0.6163634407047685, 0.25576116338263727]
# ODE | Ideal ReLU | Val1 | [0.08112632837473949, 0.6163634407047685, 0.25576116338263727]
# ODE | z @ t=T | Float32[0.15006897, 0.5951658, 0.30472955]
# ODE | Input | Float32[-0.14537819, 0.36940807, 0.0]
# ODE | z @ t=0 | Float32[-0.14317088, 0.2226353, -0.032282382]
# ===========================
# ODE | Input | Float32[0.041590087, -0.81565696, 0.0]
# ODE | Ideal Before ReLU | [-0.24557501202555584, -1.224080150931354, -0.3801960345809201]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[0.29039085, -0.6712414, 0.25475925]
# ODE | Input | Float32[0.041590087, -0.81565696, 0.0]
# ODE | z @ t=0 | Float32[0.004159013, -0.699835, -0.029415764]
# ===========================
# ODE | Input | Float32[-0.81342715, 0.33958003, 0.0]
# ODE | Ideal Before ReLU | [-0.8595131064446245, 0.12713879502224515, -0.08836571770906781]
# ODE | Ideal ReLU | Val1 | [0.0, 0.12713879502224515, 0.0]
# ODE | z @ t=T | Float32[-0.9407603, 0.4807799, 0.27623528]
# ODE | Input | Float32[-0.81342715, 0.33958003, 0.0]
# ODE | z @ t=0 | Float32[-0.75080824, 0.29359204, -0.013985243]
# ===========================
# ODE | Input | Float32[0.8212524, 0.30224687, 0.0]
# ODE | Ideal Before ReLU | [1.3876438110282463, 1.141454686445034, 0.6860021476543935]
# ODE | Ideal ReLU | Val1 | [1.3876438110282463, 1.141454686445034, 0.6860021476543935]
# ODE | z @ t=T | Float32[0.9465962, 0.69591254, 0.34592447]
# ODE | Input | Float32[0.8212524, 0.30224687, 0.0]
# ODE | z @ t=0 | Float32[0.52739835, 0.17599362, -0.03209643]
# ===========================
# ODE | Input | Float32[-0.49218258, -0.570161, 0.0]
# ODE | Ideal Before ReLU | [-0.8640063096054046, -1.1687216305981383, -0.48989630456776057]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[-0.19151887, -0.22877845, 0.24726304]
# ODE | Input | Float32[-0.49218258, -0.570161, 0.0]
# ODE | z @ t=0 | Float32[-0.41696328, -0.46359003, -0.040564436]
# ===========================
# ODE | Input | Float32[-0.36009333, -0.18826225, 0.0]
# ODE | Ideal Before ReLU | [-0.4921444500379031, -0.4489948267143874, -0.19114297470244754]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[-0.076257214, 0.11195443, 0.26840705]
# ODE | Input | Float32[-0.36009333, -0.18826225, 0.0]
# ODE | z @ t=0 | Float32[-0.3124578, -0.17736924, -0.036692716]
# ===========================
# ODE | Input | Float32[0.3282868, -0.05386581, 0.0]
# ODE | Ideal Before ReLU | [0.5283663762164612, 0.22687380767927748, 0.22706227080267768]
# ODE | Ideal ReLU | Val1 | [0.5283663762164612, 0.22687380767927748, 0.22706227080267768]
# ODE | z @ t=T | Float32[0.55773705, 0.25213182, 0.30221108]
# ODE | Input | Float32[0.3282868, -0.05386581, 0.0]
# ODE | z @ t=0 | Float32[0.2062176, -0.07524274, -0.033444457]
# ===========================
# ODE | Input | Float32[-0.16230154, 0.16368458, 0.0]
# ODE | Ideal Before ReLU | [-0.04402766376502962, 0.26435925821903083, 0.12127691857076439]
# ODE | Ideal ReLU | Val1 | [0.0, 0.26435925821903083, 0.12127691857076439]
# ODE | z @ t=T | Float32[0.13189983, 0.424249, 0.29315773]
# ODE | Input | Float32[-0.16230154, 0.16368458, 0.0]
# ODE | z @ t=0 | Float32[-0.15674147, 0.077333264, -0.034079645]
# ===========================
# ODE | Input | Float32[0.4444972, 0.8377758, 0.0]
# ODE | Ideal Before ReLU | [1.1302104996714202, 1.78073902760418, 0.830845244629073]
# ODE | Ideal ReLU | Val1 | [1.1302104996714202, 1.78073902760418, 0.830845244629073]
# ODE | z @ t=T | Float32[0.76577324, 1.1081804, 0.36136654]
# ODE | Input | Float32[0.4444972, 0.8377758, 0.0]
# ODE | z @ t=0 | Float32[0.2736007, 0.49060693, -0.03275411]
# ===========================
# ODE | Input | Float32[-0.32008925, -0.329075, 0.0]
# ODE | Ideal Before ReLU | [-0.5063104627267885, -0.6559709835840951, -0.2580335405091544]
# ODE | Ideal ReLU | Val1 | [0.0, 0.0, 0.0]
# ODE | z @ t=T | Float32[-0.023277136, -0.018009726, 0.2634694]
# ODE | Input | Float32[-0.32008925, -0.329075, 0.0]
# ODE | z @ t=0 | Float32[-0.2806333, -0.2813466, -0.0378897]
# ===========================

# %%
plot()
xplot = [i for i in 1:length(train)]
yideals = [idealx, idealz]
yodes = [odex, odez]
J = 3 # 1, 2, 3 are for first, second, third coordinates
for yi in [2] # 1 is for x , 2 is for z
    yideal = yideals[yi]
    yode = yodes[yi]
    colors = ["blue", "green", "orange"]
    markershapes = [:circle, :rect]
    g = scatter!(xplot, getindex.(yideal, J), mc=colors[J],  markershape=:circle) 
    g = scatter!(xplot, getindex.(yode, J), mc=colors[J], markershape=:xcross)
    yidealJ = getindex.(yideal, J)
    yodeJ = getindex.(yode, J)
    for xi in eachindex(xplot)
        plot!([xi, xi], [yidealJ[xi], yodeJ[xi]], linewidth=2, color=:red)
    end

    
end
scatter!([0], [0], legend=:none)

# %%
# Out:
# 19-element Vector{Float64}:
#   3.0
#   1.0051105412506975
#   0.9457003922474211
#   1.2468537845343666
#   0.5525402311145169
#   1.0930934353079695
#   0.878585875709018
#   1.2694906743546757
#   1.3055274565840618
#   1.077519600009089
#   0.1
#   0.1
#   0.1
#   0.789234359882783
#   0.3255546880870426
#  -1.1643838938969744
#   0.5
#   0.0
#   1.0

# %%
print(fsol)
plot(fsol)
# Out:
# ODESolution{Float32, 2, Vector{Vector{Float32}}, Nothing, Nothing, Vector{Float64}, Vector{Vector{Vector{Float32}}}, ODEProblem{Vector{Float32}, Tuple{Float64, Float64}, true, Vector{Any}, ODEFunction{true, SciMLBase.AutoSpecialize, FunctionWrappersWrappers.FunctionWrappersWrapper{Tuple{FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{Float32}, Vector{Float32}, Vector{Any}, Float64}}, FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float32}, Float32, 1}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float32}, Float32, 1}}, Vector{Any}, Float64}}, FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float32}, Float32, 1}}, Vector{Float32}, Vector{Any}, ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}}, FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float32}, Float32, 1}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float32}, Float32, 1}}, Vector{Any}, ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}}}, false}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, SymbolicIndexingInterface.SymbolCache{Nothing, Nothing, Nothing}}, Base.Pairs{Symbol, Union{}, Tuple{}, @NamedTuple{}}, SciMLBase.StandardODEProblem}, Tsit5{typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, OrdinaryDiffEq.InterpolationData{ODEFunction{true, SciMLBase.AutoSpecialize, FunctionWrappersWrappers.FunctionWrappersWrapper{Tuple{FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{Float32}, Vector{Float32}, Vector{Any}, Float64}}, FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float32}, Float32, 1}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float32}, Float32, 1}}, Vector{Any}, Float64}}, FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float32}, Float32, 1}}, Vector{Float32}, Vector{Any}, ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}}, FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float32}, Float32, 1}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float32}, Float32, 1}}, Vector{Any}, ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}}}, false}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, SymbolicIndexingInterface.SymbolCache{Nothing, Nothing, Nothing}}, Vector{Vector{Float32}}, Vector{Float64}, Vector{Vector{Vector{Float32}}}, Nothing, OrdinaryDiffEq.Tsit5Cache{Vector{Float32}, Vector{Float32}, Vector{Float32}, typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, Nothing}, SciMLBase.DEStats, Nothing}(Vector{Float32}[[-0.32008925, -0.329075, 0.0], [0.18275113, 0.17342344, 0.31820267]], nothing, nothing, [0.0, 1.0], Vector{Vector{Float32}}[[[-0.32008925, -0.329075, 0.0]], [[0.3711724, 0.3960396, 0.16590196], [0.37085596, 0.39574552, 0.16568524], [0.37053, 0.39544243, 0.16546232], [0.36940455, 0.39439532, 0.16469419], [0.36924738, 0.394249, 0.16458713], [0.36920816, 0.39421248, 0.16456042], [0.3692082, 0.3942125, 0.16456047]]], ODEProblem{Vector{Float32}, Tuple{Float64, Float64}, true, Vector{Any}, ODEFunction{true, SciMLBase.AutoSpecialize, FunctionWrappersWrappers.FunctionWrappersWrapper{Tuple{FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{Float32}, Vector{Float32}, V ...
# .DEFAULT_OBSERVED, nothing, SymbolicIndexingInterface.SymbolCache{Nothing, Nothing, Nothing}(nothing, nothing, nothing)), Float32[-0.32008925, -0.329075, 0.0], (0.0, 1.0), Any[-0.32008925f0, -0.329075f0, 0.0f0, 3.0, 1.0051105412506975, 0.9457003922474211, 1.2468537845343666, 0.5525402311145169, 1.0930934353079695, 0.878585875709018, 1.2694906743546757, 1.3055274565840618, 1.077519600009089, 0.1, 0.1, 0.1, 0.789234359882783, 0.3255546880870426, -1.1643838938969744, 0.5, 0.0, 1.0], Base.Pairs{Symbol, Union{}, Tuple{}, @NamedTuple{}}(), SciMLBase.StandardODEProblem()), Tsit5(; stage_limiter! = trivial_limiter!, step_limiter! = trivial_limiter!, thread = static(false),), OrdinaryDiffEq.InterpolationData{ODEFunction{true, SciMLBase.AutoSpecialize, FunctionWrappersWrappers.FunctionWrappersWrapper{Tuple{FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{Float32}, Vector{Float32}, Vector{Any}, Float64}}, FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float32}, Float32, 1}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float32}, Float32, 1}}, Vector{Any}, Float64}}, FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float32}, Float32, 1}}, Vector{Float32}, Vector{Any}, ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}}, FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float32}, Float32, 1}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float32}, Float32, 1}}, Vector{Any}, ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}}}, false}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, SymbolicIndexingInterface.SymbolCache{Nothing, Nothing, Nothing}}, Vector{Vector{Float32}}, Vector{Float64}, Vector{Vector{Vector{Float32}}}, Nothing, OrdinaryDiffEq.Tsit5Cache{Vector{Float32}, Vector{Float32}, Vector{Float32}, typeof(OrdinaryDiffEq.trivial_limiter!), typeof(OrdinaryDiffEq.trivial_limiter!), Static.False}, Nothing}(ODEFunction{true, SciMLBase.AutoSpecialize, FunctionWrappersWrappers.FunctionWrappersWrapper{Tuple{FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{Float32}, Vector{Float32}, Vector{Any}, Float64}}, FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float32}, Float32, 1}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float32}, Float32, 1}}, Vector{Any}, Float64}}, FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float32}, Float32, 1}}, Vector{Float32}, Vector{Any}, ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}}, FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float32}, Float32, 1}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float32}, Float32, 1}}, Vector{Any}, ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}}}, false}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, SymbolicIndexingInterface.SymbolCache{Nothing, Nothing, Nothing}}(FunctionWrappersWrappers.FunctionWrappersWrapper{Tuple{FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{Float32}, Vector{Float32}, Vector{Any}, Float64}}, FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float32}, Float32, 1}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float32}, Float32, 1}}, Vector{Any}, Float64 ...

# %%
plot(bsol)

# %%
params
# Out:
# 19-element Vector{Float64}:
#   3.0
#   1.0051105412506975
#   0.9457003922474211
#   1.2468537845343666
#   0.5525402311145169
#   1.0930934353079695
#   0.878585875709018
#   1.2694906743546757
#   1.3055274565840618
#   1.077519600009089
#   0.1
#   0.1
#   0.1
#   0.789234359882783
#   0.3255546880870426
#  -1.1643838938969744
#   0.5
#   0.0
#   1.0

# %%
a = [1, 2, 3]
b = [2, 4, 6]
a./b
# Out:
# 3-element Vector{Float64}:
#  0.5
#  0.5
#  0.5

# %%
dims, theta, beta, w, h, _, _ = sequester_params(params)
index = 2
xplot = sort!(rand(Uniform(-1, 1), 100))
yplot = []
for i in eachindex(xplot)
    x = zeros(dims)
    x[index] = xplot[i]
    rho = theta*x + beta
    rhoindex = rho[index]
    push!(yplot, (rhoindex + sqrt(rhoindex^2 + 1))/2)
end
plot(xplot, yplot)

# %% [markdown]
# ## Searching for more simpler activation functions with ODEs

# %%
function fx(u, p, t)
